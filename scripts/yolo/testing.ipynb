# %%
import set_path

# %%
# %pip install torch torchvision torchaudio
# %pip install ultralytics
# %pip install clearml
# %pip install tensorboard
# Out:
# ...
#   Using cached torch-2.5.1-cp39-none-macosx_11_0_arm64.whl.metadata (28 kB)
# ...
#   Using cached torchvision-0.20.1-cp39-cp39-macosx_11_0_arm64.whl.metadata (6.1 kB)
# ...
#   Using cached torchaudio-2.5.1-cp39-cp39-macosx_11_0_arm64.whl.metadata (6.4 kB)
# ...
#   Using cached filelock-3.16.1-py3-none-any.whl.metadata (2.9 kB)
# ...
#   Using cached networkx-3.2.1-py3-none-any.whl.metadata (5.2 kB)
# ...
#   Using cached jinja2-3.1.4-py3-none-any.whl.metadata (2.6 kB)
# ...
#   Using cached fsspec-2024.10.0-py3-none-any.whl.metadata (11 kB)
# ...
#   Using cached sympy-1.13.1-py3-none-any.whl.metadata (12 kB)
# ...
#   Using cached mpmath-1.3.0-py3-none-any.whl.metadata (8.6 kB)
# ...
#   Using cached numpy-2.0.2-cp39-cp39-macosx_14_0_arm64.whl.metadata (60 kB)
# ...
#   Using cached pillow-11.0.0-cp39-cp39-macosx_11_0_arm64.whl.metadata (9.1 kB)
# ...
#   Using cached MarkupSafe-3.0.2-cp39-cp39-macosx_11_0_arm64.whl.metadata (4.0 kB)
# Using cached torch-2.5.1-cp39-none-macosx_11_0_arm64.whl (63.9 MB)
# ...

# %%
import torch
import ultralytics
from ultralytics import YOLO
import tensorboard

ultralytics.checks()
# Out:
# Ultralytics 8.3.37 🚀 Python-3.9.6 torch-2.5.1 CPU (Apple M2 Max)
# Setup complete ✅ (12 CPUs, 32.0 GB RAM, 436.8/926.4 GB disk)

# %%
# Load a model
model = YOLO("/Users/moumen_momi/Documents/test_pro/runs/detect/train/weights/best.pt")

# Perform object detection on an image
results = model("/Users/moumen_momi/Documents/test_pro/datasets/SKU-110K/images/test_0.jpg")  # Replace with your test image path
results[0].show()  # Display image with predictions
# Out:
# image 1/1 /Users/moumen_momi/Documents/test_pro/datasets/SKU-110K/images/test_0.jpg: 640x480 146 objects, 63.1ms
# Speed: 4.1ms preprocess, 63.1ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 480)
