# %%
import set_path

# %% [markdown]
# YOLOv11

# %%
# %pip install torch torchvision torchaudio
# %pip install ultralytics
# %pip install clearml
# %pip install tensorboard
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# ...
# Note: you may need to restart the kernel to use updated packages.
# ...
# Note: you may need to restart the kernel to use updated packages.
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import torch
import ultralytics
from ultralytics import YOLO
import clearml
#run clearml-init in the terminal
from clearml import Task
import tensorboard

ultralytics.checks()
# Out:
# Ultralytics 8.3.31 🚀 Python-3.8.20 torch-2.4.1 CPU (Apple M2 Max)
# Setup complete ✅ (12 CPUs, 32.0 GB RAM, 433.4/926.4 GB disk)

# %%
# In terminal , keep in background
# !clearml-agent daemon --queue "default" --foreground
# Out:
# ^C

# %%
task = Task.init(
    project_name="Yolo model sku",
    task_name="Model sku training"
)



# Load a model variant
model_variant = "yolo11n"
task.set_parameter("model_variant", model_variant)

# Load the model
model=YOLO(f"{model_variant}.pt")

# Step 4: Setting Up Training Arguments
args = dict(data="SKU-110K.yaml", epochs=100, imgsz=640)
task.connect(args)

# Step 5: Initiating Model Training
results = model.train(**args)

task.close()


"""
# Train the model
train_results = model.train(
    data="/Users/moumen_momi/Documents/test_pro/data/patches_dataset/dataset.yaml",  # path to dataset YAML
    epochs=50,  # number of training epochs
    imgsz=640,  # training image size
    device = 0 if torch.cuda.is_available() else "mps" if torch.backends.mps.is_available() else "cpu" # device to run on
)

# Evaluate model performance on the validation set
metrics = model.val()

# Perform object detection on an image
results = model("data/patches_dataset/images/test/image_0__patch_0.jpg")  # Replace with your test image path
results[0].show()  # Display image with predictions

# Export the model to ONNX format
path = model.export(format="onnx")  # return path to exported model
"""
# Out:
# ...
# ClearML Task: created new task id=93cde3cb4621411e857712d258dc34d5
# 2024-11-25 16:00:14,398 - clearml.Task - INFO - Storing jupyter notebook directly as code
# ClearML results page: https://app.5ccsagap.er.kcl.ac.uk/projects/20587f1b8ccc49a2ad50f0f2903c5e88/experiments/93cde3cb4621411e857712d258dc34d5/output/log
# 2024-11-25 16:00:16,428 - clearml.model - INFO - Selected model id: 08c8921dcef94021921b9fd46a0d3e3a
# New https://pypi.org/project/ultralytics/8.3.37 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.3.31 🚀 Python-3.8.20 torch-2.4.1 CPU (Apple M2 Max)
# ...
